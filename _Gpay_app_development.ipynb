# %%
def gpay():
    gpay_access={1:"account opening",
                 2:"recharge plans",
                 3:"eb bills",
                 4:"bank transfer",
                 5:"metro ticket booking",
                 6:"balance enquiry",
                 7:"cibil score",
                 8:"gpay help support",
                 9:"feedback and ratings",
                 10:"exit"
                }
    user=int(input("enter number:"))
    if user==1:
        print("account openings")
        import random
        user=input("name:")
        ph_no=int(input("enter phone number:"))
        if len(str(ph_no))==10:
            otp=random.randint(1000,9999)
            print(f"dont share this anyone,{otp},fill it in 30 secs")
            user=int(input("enter otp:"))
            if user==otp:
                print("phone number verified")
                sms=input("enter sms")
                if sms=="recieved":
                    print("sms verification successful")
                    card_num=input("card number:")
                    if len(card_num)==16:
                        print(" debit card verified")
                        upi=input("create upi id:")
                        print("verification completed")
                        print("account opened successfully")
    elif user==2:
        print("recharge plans")
        recharge={1:'airtel',
                 2:'jio',
                 3:"vi"}
        user=input("specific sim:")
        for rec in recharge:
            if user=="airtel":
                print("airtel plans")
                plans={1:"299rs-1.5gb/day unlimited calls 28days",
                2:"409rs-2.5gb/day unlimited calls 28days",
                3:"799rs-1.5gb/day unlimited calls 84days"}
                for l in plans:
                    print("for",plans[l],"select:",l)
                user=int(input("recharge plan:"))
                if user==1:
                    ph_no=int(input("enter phone number:"))
                    amount=int(input("enter amount:"))
                    pin=int(input("enter pin:"))
                    if len(str(pin))==4:
                        print("recharged successfully")
                       
                elif user==2:
                    ph_no=int(input("enter phone number:"))
                    amount=int(input("enter amount:"))
                    pin=input("enter pin:")           
                    if len(pin)==4:
                        print("recharged successfully")
                            
                elif user==3:
                    ph_no=int(input("enter phone number:"))
                    amount=int(input("enter amount:"))
                    pin=int(input("enter pin:"))
                    if len(str(pin))==4:
                        print("recharged successfully")
                           
            elif user=="jio":
                        print("jio plans")
                        plans={1:"299rs-1.5gb/day unlimited calls 28days",
                        2:"399rs-2.5gb/day unlimited calls 28days",
                        3:"799rs-1.5gb/day unlimited calls 84days"}
                        for l in plans:
                            print("for",plans[l],"select:",l)
                        user=int(input("recharge plan:"))
                        if user==1:
                            ph_no=int(input("enter phone number:"))
                            amount=int(input("enter amount:"))
                            pin=int(input("enter pin:"))
                            if len(str(pin))==4:
                                print("recharged successfully")
                                   
                        elif user==2:
                            ph_no=int(input("enter phone number:"))
                            amount=int(input("enter amount:"))
                            pin=int(input("enter pin:"))
                            if len(str(pin))==4:
                                print("recharged successfully")
                                  
                        elif user==3:
                            ph_no=int(input("enter phone number:"))
                            amount=int(input("enter amount:"))
                            pin=int(input("enter pin:"))
                            if len(str(pin))==4:
                                print("recharged successfully")
                                 
                                
            elif user=="vi":
                print("vi plans")
                plans={1:"299rs-1.5gb/day unlimited calls 28days",
                        2:"399rs-2.5gb/day unlimited calls 28days",
                        3:"799rs-1.5gb/day unlimited calls 84days"}
                for l in plans:
                    print("for",plans[l],"select:",l)
                user=int(input("recharge plan:"))
                if user==1:
                    ph_no=int(input("enter phone number:"))
                    amount=int(input("enter amount:"))
                    pin=int(input("enter pin:"))
                    if len(str(pin))==4:
                        print("recharged successfully")
                          
                elif user==2:
                    ph_no=int(input("enter phone number:"))
                    amount=int(input("enter amount:"))
                    pin=int(input("enter pin:"))
                    if len(str(pin))==4:
                        print("recharged successfully")
                         
                elif user==3:
                    ph_no=int(input("enter phone number:"))
                    amount=int(input("enter amount:"))
                    pin=int(input("enter pin:"))
                    if len(str(pin))==4:
                        print("recharged successfully")
                           
                        
    elif user==3:
        print("EB bill payment")
        user=input("state:")
        if user=="tamilnadu":
            print("Tamil Nadu Electricity Board")
            name=input("card holder name:")
            cons_no=int(input("consumer number"))
            if len(str(cons_no))==12:
                print("bill generated")
                amount=int(input("enter amout"))
                pin=input("enter pin number:")
                if len(pin)==4:
                    print("Eb bill payment successfull")
    elif user==4:
        print("Bank transfer processing")
        reciever_name=input("reciever name:")
        acc_no=int(input("enter acc no:"))
        if len(str(acc_no))==15:
            ifsc_code=input("enter ifsc code:")
            if len(ifsc_code)==11:
                amount=int(input("enter amount:"))
                pin=int(input("enter pin:"))
                if len(str(pin))==4:
                    print("amount transaction successfull")
    elif user==5:
        print("metro ticket booking")
        route=["alandur,ashok nagar,guindy,saidapet,thousand lights,koyambedu,anna nagar east,central,highcourt,thiruvottriyur"]
        user_from=input("from:")
        user_dest=input("destination:")
        ph_num=input("enter phone number:")
        if len(str(ph_num))==10:
            amount=int(input("enter amount:"))
            pin=int(input("enter pin:"))
            if len(str(pin))==4:
                print("ticket generated on your what's app number")
    elif user==6:
        print("balance enquiry process")
        set=True
        while set:
            pin=int(input("enter pin number:"))
            if len(str(pin))==4:
                print("show available balance")
                set=False
    elif user==7:
        print("to check cibil score")
        acc_no=int(input("enter acc no:"))
        pin_no=int(input("enter pin no:"))
        if len(str(acc_no))==15 and len(str(pin_no))==4:
            print("current cibil score")
            print()
            cibil_score=int(input("enter cibil score:"))
            if cibil_score>=300 and cibil_score<=500:
                print("poor cibil score")
            elif cibil_score>=500 and cibil_score<=700:
                print("moderate cibil score")
            else:
                print("excellent cibil score")
    elif user==8:
        print("welcome to gpay help support")
        print("are you facing issues?")
        help={1:"payment got stucked",
             2:"to change upi pin",
             }
        for h in help:
            print(help)
            user=int(input("request:"))
            if user==1:
                print("stuck payment")
                print()
                print("payment will fall back to your account in three working days")
                
            elif user==2:
                print("to change upi pin")
                existing_pin=int(input("enter existing pin:"))
                if len(str(existing_pin))==6:
                    new_pin=int(input("enter new pin:"))
                    if len(str(new_pin))==6:
                        print("pin changed successfully")
                        
    elif user==9:
        print("feedback and rating")
        rating={1:"poor",
                2:"fair",
                3:"average",
                4:"good",
                5:"excellent"}
        for r in rating:
            print("for",rating[r],"select:",r)
        user=int(input("enter the number:"))
        if user==1:
            print("poor")
            user=input("feedback:")
            print("thanks for your ratings and feedback")
        elif user==2:
            print("fair")
            user=input("feedback:")
            print("thanks for your ratings and feedback")
        elif user==3:
            print("average")
            user=input("feedback:")
            print("thanks for your ratings and feedback")
        elif user==4:
            print("good")
            user=input("feedback:")
            print("thanks for your ratings and feedback")
        elif user==5:
            print("excellent")
            user=input("feedback:")
            print("thanks for your ratings and feedback")
    elif user==10:
        print("exit")
        print("thanks for using")
        
gpay()
# Out:
# enter number: 1
# account openings
# name: senthil
# enter phone number: 1234567890
# dont share this anyone,1257,fill it in 30 secs
# enter otp: 1257
# phone number verified
# enter sms recieved
# sms verification successful
# card number: 1234567890123456
#  debit card verified
# create upi id: senthil@12
# verification completed
# account opened successfully
